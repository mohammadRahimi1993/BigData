# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammadRahimi1993/BigData/blob/main/HadoopProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Step 1:Installing Hadoop

# %%
# !wget https://downloads.apache.org/hadoop/common/hadoop-3.2.4/hadoop-3.2.4.tar.gz
# !tar -xzvf hadoop-3.2.4.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# hadoop-3.2.4/share/doc/hadoop/hadoop-yarn/hadoop-yarn-server/hadoop-yarn-server-common/apidocs/org/apache/hadoop/yarn/server/records/package-summary.html
# hadoop-3.2.4/share/doc/hadoop/hadoop-yarn/hadoop-yarn-server/hadoop-yarn-server-common/apidocs/org/apache/hadoop/yarn/server/api/
# hadoop-3.2.4/share/doc/hadoop/hadoop-yarn/hadoop-yarn-server/hadoop-yarn-server-common/apidocs/org/apache/hadoop/yarn/server/api/CollectorNodemanagerProtocol.html
# hadoop-3.2.4/share/doc/hadoop/hadoop-yarn/hadoop-yarn-server/hadoop-yarn-server-common/apidocs/org/apache/hadoop/yarn/server/api/class-use/
# hadoop-3.2.4/share/doc/hadoop/hadoop-yarn/hadoop-yarn-server/hadoop-yarn-server-common/apidocs/org/apache/hadoop/yarn/server/api/class-use/CollectorNodemanagerProtocol.html
# hadoop-3.2.4/share/doc/hadoop/hadoop-yarn/hadoop-yarn-server/hadoop-yarn-server-common/apidocs/org/apache/hadoop/yarn/server/api/class-use/SCMUploaderProtocol.html
# ...

# %% [markdown]
# # Step2:Configuring Hadoop’s Java Home

# %%
#copy  hadoop file to user/local
# !cp -r hadoop-3.2.4/ /usr/local/

# %%
#To find the default Java path
# export JAVA_HOME=/usr/lib/jvm/java-11-openjdk-amd64/
# !readlink -f /usr/bin/java | sed "s:bin/java::"
# Out:
# /usr/lib/jvm/java-11-openjdk-amd64/

# %% [markdown]
# # Step 3: Running Hadoop

# %%
#Running Hadoop
# !/usr/local/hadoop-3.2.4/bin/hadoop
# Out:
# Usage: hadoop [OPTIONS] SUBCOMMAND [SUBCOMMAND OPTIONS]
#  or    hadoop [OPTIONS] CLASSNAME [CLASSNAME OPTIONS]
#   where CLASSNAME is a user-provided Java class
#
#   OPTIONS is none or any of:
#
# buildpaths                       attempt to add class files from build tree
# --config dir                     Hadoop config directory
# --debug                          turn on shell script debug mode
# --help                           usage information
# hostnames list[,of,host,names]   hosts to use in slave mode
# hosts filename                   list of hosts to use in slave mode
# loglevel level                   set the log4j level for this command
# workers                          turn on worker mode
#
#   SUBCOMMAND is one of:
#
#
#     Admin Commands:
#
# daemonlog     get/set the log level for each daemon
#
#     Client Commands:
#
# archive       create a Hadoop archive
# checknative   check native Hadoop and compression libraries availability
# ...

# %%
# !mkdir ~/input

# %%
# !cp /usr/local/hadoop-3.2.4/etc/hadoop/*.xml ~/input

# %%
# !ls ~/input
# Out:
# capacity-scheduler.xml	hdfs-site.xml	 kms-site.xml
# core-site.xml		httpfs-site.xml  mapred-site.xml
# hadoop-policy.xml	kms-acls.xml	 yarn-site.xml

# %%
# !/usr/local/hadoop-3.2.4/bin/hadoop jar /usr/local/hadoop-3.2.4/share/hadoop/mapreduce/hadoop-mapreduce-examples-3.2.4.jar grep ~/input ~/grep_example 'allo'
# !cat ~/grep_example/*
# Out:
# 2022-12-12 19:12:17,287 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2022-12-12 19:12:17,633 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2022-12-12 19:12:17,633 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2022-12-12 19:12:17,940 INFO input.FileInputFormat: Total input files to process : 9
# 2022-12-12 19:12:17,987 INFO mapreduce.JobSubmitter: number of splits:9
# 2022-12-12 19:12:18,486 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1396573162_0001
# 2022-12-12 19:12:18,486 INFO mapreduce.JobSubmitter: Executing with tokens: []
# 2022-12-12 19:12:18,749 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 2022-12-12 19:12:18,753 INFO mapreduce.Job: Running job: job_local1396573162_0001
# 2022-12-12 19:12:18,763 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# ...

# %%
# !wget http://qwone.com/~jason/20Newsgroups/20news-18828.tar.gz
# !tar -xzvf 20news-18828.tar.gz

# %% [markdown]
# # Hadoop Streaming

# %%
# !find / -name 'hadoop-streaming*.jar'
# Out:
# find: ‘/proc/46/task/46/net’: Invalid argument
# find: ‘/proc/46/net’: Invalid argument
# /usr/local/hadoop-3.2.4/share/hadoop/tools/lib/hadoop-streaming-3.2.4.jar
# /usr/local/hadoop-3.2.4/share/hadoop/tools/sources/hadoop-streaming-3.2.4-test-sources.jar
# /usr/local/hadoop-3.2.4/share/hadoop/tools/sources/hadoop-streaming-3.2.4-sources.jar
# /content/hadoop-3.2.4/share/hadoop/tools/lib/hadoop-streaming-3.2.4.jar
# /content/hadoop-3.2.4/share/hadoop/tools/sources/hadoop-streaming-3.2.4-test-sources.jar
# /content/hadoop-3.2.4/share/hadoop/tools/sources/hadoop-streaming-3.2.4-sources.jar

# %%
# !chmod u+rwx /content/mapSport.py
# !chmod u+rwx /content/reduceSport.py
# !/usr/local/hadoop-3.2.4/bin/hadoop jar /usr/local/hadoop-3.2.4/share/hadoop/tools/lib/hadoop-streaming-3.2.4.jar -input /content/20news-18828/alt.atheism/49960 -output /content/output -file /content/mapper.py  -file /content/reducer.py  -mapper 'python mapper.py'  -reducer 'python reducer.py'
# !cat /content/output/part-00000

# %% [markdown]
# # Pizza Dataset

# %%
# !chmod u+rwx /content/mapPizza.py
# !chmod u+rwx /content/reducePizza.py
# !/usr/local/hadoop-3.2.4/bin/hadoop jar /usr/local/hadoop-3.2.4/share/hadoop/tools/lib/hadoop-streaming-3.2.4.jar -input /content/pizza.xlsx -output /content/output -file /content/mapPizza.py -file /content/reducePizza.py  -mapper 'python mapPizza.py'  -reducer 'python reducePizza.py'
# Out:
# 2022-12-12 19:15:23,209 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [/content/mapPizza.py, /content/reducePizza.py] [] /tmp/streamjob15768639352528250865.jar tmpDir=null
# 2022-12-12 19:15:23,984 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2022-12-12 19:15:24,224 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2022-12-12 19:15:24,224 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2022-12-12 19:15:24,289 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2022-12-12 19:15:24,529 INFO mapred.FileInputFormat: Total input files to process : 1
# 2022-12-12 19:15:24,562 INFO mapreduce.JobSubmitter: number of splits:1
# 2022-12-12 19:15:24,968 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local726172705_0001
# 2022-12-12 19:15:24,968 INFO mapreduce.JobSubmitter: Executing with tokens: []
# ...

# %%
# !cat /content/output/part-00000
# Out:
# [0, 'cheese', 'large', 19, 15, '2016-08-24t12:30:28']	1
# [1, 'cheese', 'large', 20, 45, '2006-02-07t13:47:55']	1
# [10, 'cheese', 'medium', 28, 20, '1980-11-29t14:50:57']	1
# [100, 'vegan', 'small', 15, 15, '2000-02-27t08:52:20']	1
# [101, 'cheese', 'large', 10, 15, '1996-03-13t01:28:27']	1
# [102, 'cheese', 'small', 14, 50, '2002-10-18t04:18:00']	1
# [103, 'pepperoni', 'small', 10, 30, '1977-02-26t22:19:17']	1
# [104, 'cheese', 'medium', 20, 50, '2008-02-07t08:22:33']	1
# [105, 'vegan', 'large', 19, 45, '2000-02-20t10:11:24']	1
# [106, 'vegan', 'large', 23, 35, '1985-08-28t06:40:54']	1
# [107, 'vegan', 'small', 19, 10, '2010-10-15t00:27:59']	1
# [108, 'pepperoni', 'medium', 22, 50, '1997-01-25t12:50:32']	1
# [109, 'vegan', 'large', 14, 40, '1989-04-14t18:06:09']	1
# [11, 'pepperoni', 'small', 30, 45, '1988-10-03t22:43:39']	1
# [110, 'pepperoni', 'large', 16, 50, '1984-05-19t12:32:21']	1
# [111, 'vegan', 'small', 26, 15, '2001-04-27t08:58:44']	1
# ...

# %% [markdown]
# # Sport Dataset

# %%
# !chmod u+rwx /content/mapSport.py
# !chmod u+rwx /content/reduceSport.py
# !/usr/local/hadoop-3.2.4/bin/hadoop jar /usr/local/hadoop-3.2.4/share/hadoop/tools/lib/hadoop-streaming-3.2.4.jar -input /content/sport.xlsx -output /content/output1 -file /content/mapSport.py -file /content/reduceSport.py  -mapper 'python mapSport.py'  -reducer 'python reduceSport.py'
# Out:
# 2022-12-12 19:16:49,402 WARN streaming.StreamJob: -file option is deprecated, please use generic option -files instead.
# packageJobJar: [/content/mapSport.py, /content/reduceSport.py] [] /tmp/streamjob3398571462445045554.jar tmpDir=null
# 2022-12-12 19:16:50,302 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2022-12-12 19:16:50,489 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2022-12-12 19:16:50,489 INFO impl.MetricsSystemImpl: JobTracker metrics system started
# 2022-12-12 19:16:50,516 WARN impl.MetricsSystemImpl: JobTracker metrics system already initialized!
# 2022-12-12 19:16:50,665 INFO mapred.FileInputFormat: Total input files to process : 1
# 2022-12-12 19:16:50,693 INFO mapreduce.JobSubmitter: number of splits:1
# 2022-12-12 19:16:51,018 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local483133805_0001
# 2022-12-12 19:16:51,018 INFO mapreduce.JobSubmitter: Executing with tokens: []
# ...

# %%
# !cat /content/output1/part-00000
# Out:
# Reducing is:
# (['aahron', '2020-03-17t06:00:38', 'ice', 'climbing', 'tennis', 'swimming', 'gymnastics'], 1)
# (['aamer', '2002-10-11t20:37:15', 'gymnastics'], 1)
# (['aamir', '1994-02-22t15:08:22', 'golf', 'skysurfing', 'gymnastics'], 1)
# (['aamir', '2017-09-27t22:16:11', 'aikido', 'handball', 'baseball', 'swimming'], 1)
# (['aaran', '2009-03-23t18:32:08', 'racquetball', 'ice', 'climbing', 'gymnastics'], 1)
# (['aaren', '1997-10-05t13:01:59', 'baseball', 'badminton'], 1)
# (['aarin', '1988-09-08t07:32:22', 'basketball', 'volleyball', 'handball', 'gymnastics'], 1)
# (['aaron', '1972-12-30t12:01:03', 'bmx', 'handball'], 1)
# (['aaron', '1992-01-03t21:20:25', 'racquetball', 'volleyball', 'running'], 1)
# (['aaronn', '1975-04-09t08:14:23', 'racquetball', 'volleyball'], 1)
# (['aarron', '2001-12-15t16:16:03', 'handball'], 1)
# (['aaryn', '2013-09-30t01:40:17', 'gymnastics'], 1)
# (['aaryn', '2019-01-03t06:38:00', 'racquetball', 'basketball', 'tennis'], 1)
# ...
